# %%
import json
import os
from dotenv import load_dotenv
load_dotenv()
PROJECT_ID = os.getenv("PROJECT_ID")
SPACE_ID = os.getenv("SPACE_ID")
IBM_CLOUD_APIKEY = os.getenv("IBM_CLOUD_APIKEY")
IBM_CLOUD_REGION = os.getenv("IBM_CLOUD_REGION")

import ibm_watsonx_ai
from ibm_watsonx_ai import APIClient
from ibm_watsonx_ai import Credentials

credentials = Credentials(
                   url = "https://us-south.ml.cloud.ibm.com",
                   api_key = IBM_CLOUD_APIKEY,
                  )

client = APIClient(credentials)
client.set.default_space(SPACE_ID)
client.set.default_project(PROJECT_ID)
# Out:
# Unsetting the space_id ...
# 'SUCCESS'

# %%
#client.foundation_models.get_embeddings_model_specs()
conns = client.connections
conn_list = conns.list()
conns.get_details(connection_id=None)
# Out:
# {'resources': [{'metadata': {'id': '0cb5aa86-1899-4e66-83f3-89e5d8dd0a93',
#     'asset_type': 'connection',
#     'create_time': '2024-05-30T02:59:39Z',
#     'last_access_time': 1717385367241,
#     'project_id': '7e0c4482-de51-45d1-a85d-2bc5d0aa5003'},
#    'entity': {'datasource_type': '193a97c1-4475-4a19-b90c-295c4fdc6517',
#     'name': 'CloudObjectStorage'}},
#   {'metadata': {'id': '0ab32860-ac51-4543-b55d-155021a49436',
#     'asset_type': 'connection',
#     'create_time': '2024-05-30T03:21:08Z',
#     'last_access_time': 1717039503362,
#     'project_id': '7e0c4482-de51-45d1-a85d-2bc5d0aa5003'},
#    'entity': {'datasource_type': '200d71ab-24a5-4b3d-85a4-a365bdd0d4cb',
#     'name': 'WatsonxDiscovery'}}]}

# %%
from elasticsearch import AsyncElasticsearch
from llama_index.core import VectorStoreIndex, PromptTemplate, Settings
from llama_index.vector_stores.elasticsearch import ElasticsearchStore

# %%
import re
from ibm_watsonx_ai.helpers.connections import DataConnection, S3Location
from langchain_core.documents import Document

def preprocess_text(lines):
    processed_lines = []
    length = len(lines)
    
    for i in range(length):
        line = lines[i].strip()
        if line:  # check if the line is not empty
            if i + 1 < length and lines[i + 1].strip():  # Next line exists and is not empty
                if not re.search(r'[.!?]$', line):  # If line does not end with punctuation
                    line += ','
            elif not re.search(r'[.!?]$', line):  # Next line does not exist or is empty
                line += '.'
        processed_lines.append(line)
    
    return '\n'.join(processed_lines)

docs_to_retrieve = ["homepage", "methotrexate", "epipen", "folate", "ibuprofen", "prescriptionrefill", "appointment", "ra"]
metadata = [{"name": "homepage", "source": "https://corp.nhg.com.sg/Pages/Digital%20Version%202022-2023/directory.pdf"},
            {"name": "methotrexate", "source": "https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Documents/Pharmacy/PIL/PIL_by_Drug/Methotrexate_RAI_.pdf"},
            {"name": "epipen", "source": "https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Documents/Pharmacy/PIL/PIL_by_Drug/Adrenaline_Autoinjector.pdf"},
            {"name": "folate", "source": "https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Documents/Pharmacy/PIL/PIL_by_Drug/Folic_Acid.pdf"},
            {"name": "ibuprofen", "source": "https://www.healthdirect.gov.au/ibuprofen"},
            {"name": "prescriptionrefill", "source": "https://www.ttshpharmezy.nhg.com.sg/prescription"},
            {"name": "appointment", "source": "https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx"},
            {"name": "ra", "source":"https://www.ttsh.com.sg/Patients-and-Visitors/Pages/Find-Conditions-and-Treatments-Details.aspx?condition=Rheumatoid-Arthritis"}]
dataset_list = []
for i in range(len(docs_to_retrieve)):
    training_data_references = DataConnection(
        connection_asset_id='0cb5aa86-1899-4e66-83f3-89e5d8dd0a93',
        location=S3Location(bucket='10be7d6b-6c04-469f-83a8-18aad81af8bd',   # note: COS bucket name where training dataset is located
                            path=docs_to_retrieve[i]+".csv",  # note: path within bucket where your training dataset is located
                            )
    )
    training_data_references.set_client(client)
    dataset = training_data_references.read(encoding='utf-8')
    documents = dataset['0'].fillna('\n').tolist()
    processed_text = preprocess_text(documents)
    document =Document(metadata=metadata[i], page_content=processed_text)
    print(document)
    dataset_list.append(document)

#client.connections.get_details(connection_id='0cb5aa86-1899-4e66-83f3-89e5d8dd0a93')
# Out:
# page_content='TAN TOCK SENG HOSPITAL PTE LTD,\nAddress : 11 Jalan Tan Tock Seng Singapore 308433,\nTelephone: 62566011,\nWebsite: https://www.ttsh.com.sg.\n\nTan Tock Seng Hospital (TTSH) is the \uf0dfagship hospital of NHG and part of Singapore’s public healthcare system. As a pioneering hospital with strong roots in the community for over 175 years, TTSH is recognised as the People’s Hospital, serving a resident population of 1.4 million living in Central Singapore.\nTogether, with 70 community partners and 80 community health posts, it brings care beyond the hospital into,\nthe community as an Integrated Care Organisation — Central Health.\nAs one of the largest multidisciplinary hospitals in Singapore, TTSH operates more than 1,700 beds,\nwith centres of excellence including the National Centre for Infectious Diseases (NCID), Institute for Geriatrics & Active Ageing (IGA), NHG Eye Institute (NHGEI), TTSH Rehabilitation Centre, and Ang Mo Kio Specialist Centre (AMKSC).\nTTSH’s 600-bed Integrated Care Hub will be ready in 2023 to provide for sub-acute care and rehabilitation.\nAs a healthcare leader in population health, systems innovation, health technologies and workforce transformation, TTSH hosts Singapore’s largest purpose- built innovation centre for healthcare — the Ng Teng Fong Centre for Healthcare Innovation (CHI) and its Co- Learning Network of 37 local and international partners.' metadata={'name': 'homepage', 'source': 'https://corp.nhg.com.sg/Pages/Digital%20Version%202022-2023/directory.pdf'}
# page_content='Pharmacy,\nDRUG INFORMATION: Methotrexate,\nMethotrexate,\n- Methotrexate is an immunosuppressive drug which helps to control over- activity of the immune system by interfering with some actively growing cells within the body.\n- It is used for the treatment of various autoimmune diseases e.g. rheumatoid arthritis, Systemic Lupus Erythematosus (SLE), juvenile arthritis, psoriatic arthritis, and inflammatory myositis (muscle inflammation).\n- In arthritis, Methotrexate acts as a disease modifying anti-rheumatic drug (DMARD) to help to reduce pain, swelling and long-term joint damage.\n\nHow is Methotrexate Taken?\n- A typical weekly dose of Methotrexate ranges from 7.5mg to 25mg, given in the form of tablets or injection. Dosage may vary depending on your,\ndisease activity and response to the medicine.\n- It should be swallowed whole with a glass of water. Do not chew or crush the tablets. Wash hands thoroughly after administration.\n- Folic or folinic acid (also called folate) is often given with Methotrexate to reduce the risk of some side effects. It is usually taken a day before or,\nafter Methotrexate unless advised otherwise by your doctor.\n- The beneficial effects of Methotrexate will begin after 6 weeks and the full benefits may not be seen until after 12 weeks of treatment. Thus it is,\nimportant that you take your medication regularly, otherwise you may not benefit at all.\n- If you miss a dose, take it as soon as you remember if it is within 2 days from your scheduled dose. For example, your scheduled dose is on,\nSunday, if you remember on Tuesday, take the dose on Tuesday and resume back to the Sunday schedule the next week. Skip the dose if 3 or,\nmore days have lapsed since the missed dose. Do not double the dosage to make up for the missed dose.\n\nCan Methotrexate Be Taken with Other Medications?\n- Methotrexate can be taken with other medications such as corticosteroids, non-steroidal anti-inflammatory drugs (NSAIDs) and other disease modifying agents.\n- Please inform your doctor, pharmacist or rheumatology nurse clinician if you are taking other medications including over-the-counter medicines,,\nsupplements or traditional/herbal remedies as they may interact with Methotrexate.\n- Do not drink alcohol while on this medicine as it may increase the risk of liver toxicity associated with Methotrexate.\n- Pneumococcal and influenza (flu) vaccinations are safe and may be given if required. Avoid live vaccines such as MMR (measles, mumps and rubella), OPV (oral polio vaccine), yellow fever or BCG (tuberculosis). Discuss with your doctor before receiving any vaccines.\n\nWhat are the Important Side Effects of Methotrexate?\n- Many of the side effects occur at higher doses. Due to the way Methotrexate works, some side effects may be present only after years of taking this medication. Always discuss with your doctor if you experience any side effects.\nSIDE EFFECT AND MANAGEMENT,\nMouth ulcers: Folic/folinic acid can be prescribed to reduce this side effect.\nNausea, vomiting, diarrhoea or loss of appetite: Take medication after food to minimise the side effects. Folic/folinic acid can be prescribed to reduce this side effect. Alternatively, Methotrexate can be converted to an injection form. Consult your doctor immediately if you see bloody vomit or stools.\nSlow loss of hair: It is generally reversible when the medicine is discontinued.\nSkin rashes: These usually resolve readily upon decreasing the dose or stopping the medicine.\nLung inflammation (Warning signs: Persistent coughing, breathlessness or chest pain): Consult your doctor immediately. It is advisable to stop smoking.\nLiver disorder (Warning signs: Yellowing of eye whites or skin, dark or tea- coloured urine, or constant abdominal pain): Consult your doctor immediately. Avoid alcohol. Inform your doctor if you have any liver disease (e.g. jaundice, hepatitis) or if any of your family member has,\nhepatitis.\nBlood disorders (Warning sig ...
# page_content='Adrenaline auto-injector (EpiPen and EpiPen Jr),\nMedication Information Leaflet,\nWhat is this medication for?\n-\tThis medication contains epinephrine (or commonly known as adrenaline), which is used for the emergency treatment of sudden life-threatening allergic reactions (anaphylaxis).\n-\tSymptoms of allergic reactions include:,\n-\tMouth: itch and swelling of lips, tongue, or mouth,\n-\tThroat*: itching and/or a sense of tightness in the throat, hoarseness, hacking cough,\n-\tSkin: hives, itchy rash, and/or swelling on the face or extremities,\n-\tGut: nausea, abdominal cramps, vomiting, diarrhea,\n-\tLung*: shortness of breath, repetitive coughing and/or wheezing,\n-\tHeart*: passing out, fainting, dizziness,\n-\tThe severity of symptoms can quickly change. *All these symptoms can potentially progress to a life-threatening situation.\n\nHow should I take/use this medication?\nThere are two available strengths (EpiPen and EpiPen Jr), and the doctor will decide on the suitability according to your weight.\n1\tRemove auto-injector from the carrier tube.\n2\tHold the auto-injector with tip down.\n3\tMake a fist around the auto-injector.\n4\tPull off the blue safety release. Do not put your fingers or hand over the orange tip.\n5\tHold the auto-injector at a 90� angle to the outer thigh, Swing and firmly push the orange tip against the middle of the outer thigh, through clothing if needed.\n6\tIf you are administering EpiPen or EpiPen Jr to another person, hold the leg of the person firmly to prevent injury. Push the orange tip firmly against the middle of the outer thigh, through clothing if needed.\n7\tPress hard into the outer thigh until it clicks.\n8\tHold in place for 3 seconds then remove.\n9\tThe orange tip will extend to cover the needle.\n10\tMassage the area of injection for 10 seconds.\n11\tRecord the time the auto-injector was administered.\n12\tSeek medical help immediately, by reporting to your doctor or the nearest hospital, or call the local emergency response team (call 995 if in Singapore).\n13\tEffects of the auto-injector only last for 20-30 minutes.\n14\tIf your symptoms are still present 15 minutes after the first injection, you may need a second auto-injector.\n15\tThe auto-injector is for single use only.\n16\tSee your doctor for a refill or replacement of this medication.\n\nWhat should I do if I forget to take/use this medication?\n-\tSeek medical help immediately.\nWhat precautions should I take?\n-\tThere is no known reason why anyone should not use EpiPen or EpiPen Jr during life-threatening allergic reactions as they are critical for the treatment. However, inform your healthcare professional if you:,\n-\tHave heart conditions or high blood pressure,\n-\tHave diabetes,\n-\tHave thyroid conditions,\n-\tHave asthma,\n-\tHave a history of depression,\n-\tHave Parkinson\'s disease,\n-\tHave any other medical conditions,\n-\tAre allergic to this medication, sodium metabisulfite, or any of the other ingredients of this medication.\n-\tAre pregnant, planning to become pregnant, or breastfeeding.\n-\tCheck the "viewing window" to ensure that the solution is clear and colorless. If the "viewing window" is obscured, this means that the auto-injector has been used and cannot be used again. Replace the EpiPen or EpiPen Jr if the medication appears cloudy, contains particles, or changes color (from clear solution to pink or brown color).\n-\tAlways check the expiry date indicated on the label. Replace the EpiPen and EpiPen Jr if they have expired. Do not use them after the expiry date.\n-\tDo not inject this medication into your blood vessels, buttocks, fingers, toes, hands or feet. If you accidentally inject into any of these areas, go to the nearest emergency room immediately.\n-\tAlways carry this medication with you at all times.\n\nWhat are some common side-effects of this medication?\n-\tThese common side effects may disappear with rest. If any of the following effects persist or are sev ...
# page_content='Folic Acid (Folate),\nMedication Information Leaflet,\nWhat is the medication used for?\nFolic acid (or folate) is a type of vitamin naturally found in some foods that helps the body to produce red blood cells. A lack of folic acid may result in folate-deficiency anemia, a condition in which there is insufficient healthy red blood cells to provide oxygen to the body.\nDuring pregnancy, folic acid supplementation may reduce the incidence of birth defects (e.g., abnormal development of brain and spinal cord in the baby).\nFolic acid supplementation may be required in those with certain conditions (e.g., kidney disease, excessive alcohol intake) or taking certain medications (e.g., Methotrexate, Sulfasalazine).\n\nHow should I take/use the medication?\n-\tDo not stop taking your medications without checking with your healthcare professional.\n-\tThis medication may be taken with or without food.\nWhat should I do if I forget to take/use this medication?\nIf you miss a dose, take the missed dose as soon as you remember. If it is almost time for your next dose, take only the usual dose. Do not double your dose or use extra medication to make up for the missed dose.\n\nWhat precautions should I follow when taking the medication?\nInform your healthcare professional if:,\n-\tYou are allergic to this medication, or any of the other ingredients in this medication.\n-\tYou are taking any other medications, including supplements, traditional medications, and herbal remedies.\nWhat are some common side-effects of this medication?\nGenerally, this medication is well tolerated without any significant side effects.\n\nWhat are some rare but serious side-effects that I need to seek medical advice immediately?\nThe symptoms of a drug allergy include one or more of the following:,\n-\tSwollen face/eyes/lips/tongue,\n-\tDifficulty in breathing,\n-\tItchy skin rashes over your whole body,\nIf you experience any of these symptoms, you should stop your medication and see your healthcare professional immediately.\n\nHow should I store the medication?\nStore in a cool and dry place, away from direct sunlight. Keep this medication away from children. Throw away all expired medications.\nHow should I throw away this medication safely?\nPack this medication into a black trash bag and seal it tightly before throwing it into the rubbish chute or bin.\n\nDisclaimers,\nPlease take note that the above is not a complete list of all possible side effects. If you have any concerns about your medication or if you have other side effects that you think are caused by this medication, please consult your doctor or pharmacist.\nIf you take more than the recommended dose, please seek medical advice immediately. The information provided on this page does not replace information from your healthcare professional. Please consult your healthcare professional for more information.\nThis transcription captures the key details and instructions provided in the medication leaflet for Folic Acid, focusing on its uses, dosing instructions, potential side effects, and other important precautions.' metadata={'name': 'folate', 'source': 'https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Documents/Pharmacy/PIL/PIL_by_Drug/Folic_Acid.pdf'}
# page_content="What is ibuprofen?\nIbuprofen is a type of anti-inflammatory pain-relief medicine that treats fever and mild to moderate pain caused by inflammation. It belongs to a group of medicines called non-steroidal anti-inflammatory drugs, or NSAIDs.\nHow does ibuprofen work?\nIbuprofen works on one of the body's chemical pathways for pain. It reduces your body's ability to make prostaglandins - these are the natural chemicals that trigger pain, inflammation and fever.\nWith fewer prostaglandins in your body, pain and inflammation are reduced, and your fever goes down.\n\nWhat is ibuprofen used for?\nIbuprofen can be used for the short-term relief of fever, mild to moderate pain and inflammation (redness, swelling and soreness).\nIbuprofen might also reduce some of the symptoms of:,\nheadaches (including migraines or tension headache),\nsinus pain,\ntoothache and pain after dental procedures,\nbackache and muscular aches and pains,\nperiod pain,\nsore throat,\narthritis,\nIbuprofen provides only temporary relief - it won't cure your condition.\n\nWhat are the possible side effects of ibuprofen?\nCommon side effects of ibuprofen include:,\nupset stomach e.g. nausea, diarrhoea and indigestion,\nheadache,\ndizziness,\nhigh blood pressure,\nfluid retention.\n\nSerious side effects of ibuprofen that need immediate medical attention include:,\nasthma, wheezing and shortness of breath,\nswelling of the face, lips or tongue, which may cause difficulty breathing or swallowing,\ndark vomit that looks like coffee grounds,\nblack stools that can indicate bleeding,\nThis is not a full list of side effects. For more information, talk to your doctor or pharmacist or check the consumer medicine information leaflet in your medicine packaging.\nThe dose of ibuprofen will be printed on the package. Do not take more than the maximal daily dose.\n\nAre there alternatives to ibuprofen?\nIf you're treating fever or mild to moderate pain, ask your pharmacist if you can use paracetamol in place of ibuprofen.\n\nFor pain or inflammation-related swelling, ask your doctor or pharmacist for another option if ibuprofen is not suitable for you. Your health professional may suggest you try:,\nparacetamol,\nanother medicine from the NSAID family,\na medicine that combines codeine with paracetamol or ibuprofen in the same tablet,\nIf your pain is severe, your doctor may prescribe you a stronger pain reliever." metadata={'name': 'ibuprofen', 'source': 'https://www.healthdirect.gov.au/ibuprofen'}
# page_content='Prescription Refill,\nTTSH Medication Delivery Service.\n\nPillDeliver,\nReceive your medication at the address provided.\nYou will receive an SMS containing the PIN code for your medication delivery on the day of delivery. Please ensure that someone is at the delivery address during the delivery timeslot. (Note: Medication parcels cannot be left unattended at the riser/doorstep). Quote the PIN code in the SMS to the delivery courier to receive your medication.\nThe following timeslots are available for PillDeliver:,\n9am - 1pm: Weekdays, Saturdays,\n2pm - 6pm: Weekdays, Saturdays,\n7pm - 10pm: Weekdays.\n\nPillLocker,\nCollect your medication within 3 calendar days of receiving an SMS notification.\nPillLocker locations: https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Medication-Delivery-Service/Pages/PillLocker.aspx,\nHow do I refill my prescription?\nPlease order at least 2 weeks in advance so that we can process your request.\nYou can order via:,\n1\tFormSG: https://www.form.gov.sg/604707a64f1157001163e759,\n2\tHealthHub > Personal Health > Medication Refill,\n3\tPharmEzy Website: Prescription Refill,\n4\tPhone call: 63572050, from 9.30am - 5.30pm, Mondays to Fridays (excluding Saturday and Sunday, Public Holidays and eve of Public Holidays).\n' metadata={'name': 'prescriptionrefill', 'source': 'https://www.ttshpharmezy.nhg.com.sg/prescription'}
# page_content='Appointments,\nRequest appointment,\n-\tIf you have a referral from a polyclinic doctor and do not choose your specialist doctor at our SOC, you can enjoy subsidy from the Government for your consultation and treatment.\n-\tPlease note that as a government-patient, you may be seen by subsidised different doctors during the course of your treatment. The polyclinic will usually make a specialist appointment on your behalf.\n-\tIf you have been seen by our Emergency Department doctors or are discharged from our hospital and needs specialist consultation, we will arrange and advise you on your SOC appointment.\n-\tConsultation at our Specialist Outpatient Clinics (SOC) and treatment by our Allied Health Services is by appointment only.\n-\tYou can call us directly or your general practitioner/family doctor can help to make the arrangement for you.\n-\tNotice: If it is a medical emergency, please call for an SCDF ambulance at 995 or go to our Emergency Department for medical attention.\n-\tWhat should I bring?\n-\tOn your first visit to the specialist clinic, please bring the following documents for registration:,\n-\tPersonal documents,\n-\tNRIC,\n?\tBirth Certificate (if you are below 12 years old),\n?\tPassport,\n?\tEmployment Pass/ Work Permit,\n-\tReferral letter (if any),\n-\tAny medical benefit identification documents (e.g. Civil Service Card, Medical Benefits Card, etc),\n-\tUpdate or cancel appointment,\n-\tTo cancel or update your appointment, please call 6357 7000 or email Contact@ttsh.com.sg . Calls are available during these times Mondays to Fridays 8.00 am to 5.00 and Saturdays 8.00 am to 12.00 pm.\n-\tYou may download HealthHub app to access health information and services conveniently from your mobile device.\n' metadata={'name': 'appointment', 'source': 'https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx'}
# page_content="Department of,\nRHEUMATOLOGY, ALLERGY AND IMMUNOLOGY,\nRheumatoid Arthritis,\nClinics B1A and B1B,\nTTSH Medical Centre, Level B1,\nContact: 6357 7000 (Central Hotline).\n\nWhat is Rheumatoid Arthritis?\nRheumatoid arthritis (RA) is an autoimmune disease that causes chronic inflammatory arthritis (warm, swollen, painful joints) and may affect other parts of the body including the eyes, lungs, skin, heart, blood vessels and nerves.\n\nWho are at Risk of RA?\nRA is more common in women. It usually occurs in people aged between 25 to 50 years old, but young children and elderly may be affected too.\n\nWhat Causes RA?\nThe precise cause of RA is unknown. It is likely to be caused by a combination of factors like:,\n-\tGenetics�,\n-\tAbnormal immune system�,\n-\tEnvironment (e.g. smoking, stress)�,\n-\tHormones.\n\nSymptoms and Signs of RA,\nIn early stages of RA, most people experience:�,\n-\tEarly morning stiffness�,\n-\tAching of the joints,\n(especially in hands and feet)�,\n-\tFatigue,\nOvertime, the joints become warm, painful and swollen. The same joints on both sides of the body tend to be affected, especially the hands and feet.\nPeople with RA may also:�,\n-\tLose their appetite�,\n-\tLose weight�,\n-\tDevelop depression�,\n-\tExperience general tiredness and fatigue (dependant on the amount of inflammation the patient has),\nEarly diagnosis can prevent irreversible joint damage and preserve joint function.�.\n\nHow is RA Diagnosed?\nRA is diagnosed based on,\nhistory, physical examination and laboratory tests.\nImaging may be required if RA is in its early stages or symptoms and signs appear unusual.\nThe doctor may also drain fluid from your joints to ensure your arthritis is not due to an infection or some other causes.\nYour doctor may perform a biopsy to remove small bits of inflamed joint tissue or nodules for examination only when needed.\nCommon tests performed for RA patients,\ninclude:,\n- Full blood count,\n- Kidney function and liver function tests - Inflammatory markers tests,\n- Auto-antibodies tests,\n- X-Rays of affected joints.\n\nWhat are the Treatments for RA?\n1. Patient Education,\nThis consists of empowering yourself with knowledge and taking charge of your health.\nAdvice includes:,\n- Learn as much as you can about RA.\n- Do not be afraid of arthritis. Most patients,\nwith RA lead normal lives.\n- Seek your doctor's advice early.\nAvoid unnecessary strain on affected joints.\n- Take medications as advised by your doctor.\n- Do not change the dosage or types of medication without your doctor's knowledge.\n- Do not rely on unproven remedies in hope that the disease will go away.\n- Do not change doctor unnecessarily because the treatment of RA is complex and long-term. It is best that you build a lasting relationship with your doctor.\n- Get adequate rest and sleep.\n- Join support groups like the National Arthritis Foundation. Scan the QR code below or access https://naf.org.sg/naf- membership-signup/ to join!\n2. Medication,\nMajority of patients with RA require medications.\n- Non-Steroidal Anti-inflammatory Drugs (NSAIDs),\nUsually used to reduce joint swelling, pain and stiffness.\n- Disease Modifying Anti-rheumatic Drugs (DMARDs),\nAims to suppress inflammation so that joint pain and swelling are controlled and damage to joints is minimised.\nCorticosteroids,\nOften used in low doses in combination with NSAIDs and DMARDs to enable quick control of inflammation.\n3\tPhysiotherapy (PT) and Occupational Therapy (OT),\nImprove pain control using non- pharmacological methods,\n(e.g. heat and cold therapy).\nExplore ways of improving mobility of injured joints and muscles (e.g. application of splints).�,\n4\tBiologics Agents,\nThey are medical products extracted or produced from biological sources. They are expensive and reserved for arthritis that is not controlled by standard therapy.�,\n5\tLifestyle Modification,\nQuit smoking, have adequate rest, exercise and maintain ideal body wei ...

# %%
# #turn ttsh.txt into a csv file
import pandas as pd
#for every fil in /documents folder
#read in the file
#split the file into lines
#write the lines to a csv file
#write the csv file to the data connection
training_data_references.set_client(client)

for filename in os.listdir('documents'):
    
    filename = filename.split('.')[0]
    with open('documents/'+filename + ".txt", 'r') as file:
        data = file.read()
    data = data.split('\n')
    df = pd.DataFrame(data)
    df.to_csv('documents/'+filename + '.csv', index=False)
    print(filename)
    training_data_references.write(data='documents/'+filename + '.csv', remote_name= filename + '.csv') #writing works
# Out:
# homepage
# methotrexate
# ra
# epipen
# folate
# ibuprofen
# prescriptionrefill
# appointment
# homepage
# methotrexate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 18
#      16 df.to_csv('documents/'+filename + '.csv', index=False)
#      17 print(filename)
# ---> 18 training_data_references.write(data='documents/'+filename + '.csv', remote_name= filename + '.csv') #writing works
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/ibm_watsonx_ai/helpers/connections/connections.py:1299, in DataConnection.write(self, data, remote_name, **kwargs)
#    1293 if (
#    1294     getattr(self._api_client, "ICP_PLATFORM_SPACES", False)
#    1295     and self.type == DataConnectionTypes.CN
#    1296 ):
#    1297     raise ContainerTypeNotSupported()  # block Container type on CPD
# -> 1299 if self._check_if_connection_asset_is_s3():
#    1300     # do not try Flight if we are on the cloud
#    1301     if (
#    1302         self._api_client is not None
#    1303         and not self._api_client.ICP_PLATFORM_SPACES
#    1304         and not use_flight
#    1305     ):  # CLOUD
#    1306         if remote_name is None and self._to_dict().get("location", {}).get(
#    1307             "path"
#    1308         ):
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/ibm_watsonx_ai/helpers/connections/base_data_connection.py:415, in BaseDataConnection._check_if_connection_asset_is_s3(self)
#     408 self._datasource_type = datasource_type
#     409 datasource_type_id_ibm_cos = (
#     410     self._api_client.connections.get_datasource_type_id_by_name(
#     411         "bluemixcloudobjectstorage"
#     412     )
#     413 )
#     414 datasource_type_id_aws_cos = (
# --> 415     self._api_client.connections.get_datasource_type_id_by_name(
#     416         "cloudobjectstorage"
#     417     )
#     418 )
#     420 if (
#     421     datasource_type == datasource_type_id_ibm_cos
#     422     or datasource_type == datasource_type_id_aws_cos
#     423     or datasource_type == "bluemixcloudobjectstorage"
#     424     or datasource_type == "cloudobjectstorage"
#     425 ):
#     426     cos_type = True
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/ibm_watsonx_ai/connections.py:591, in Connections.get_datasource_type_id_by_name(self, name)
#     588 Connections._validate_type(name, "name", str, True)
#     590 with self.requests_retry_session() as sess:
# --> 591     response = sess.get(
#     592         self._client.service_instance._href_definitions.get_connection_data_types_href(),
#     593         headers=self._client._get_headers(),
#     594     )
#     596     datasource_id = "None"
#     597     datasource_details = self._handle_response(
#     598         200, "list datasource types", response
#     599     )["resources"]
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/ibm_watsonx_ai/_wrappers/requests.py:35, in set_verify_for_requests.<locals>.wrapper(*args, **kw)
#      32     kw.update({"verify": True})
#      34 try:
# ---> 35     res = func(*args, **kw)
#      37 except OSError as e:
#      38
#      39     # User can pass verify the path to a CA_BUNDLE file or directory with certificates of trusted CAs
#      40     if isinstance(verify, str):
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/ibm_watsonx_ai/_wrappers/requests.py:72, in set_additional_settings_for_requests.<locals>.wrapper(*args, **kw)
#      70 kwargs.update(additional_settings)
#      71 kwargs.update(kw)
# ---> 72 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/ibm_watsonx_ai/_wrappers/requests.py:277, in Session.request(self, method, url, **kwargs)
#     275 kwargs["method"] = method
#     276 kwargs["url"] = url
# --> 277 return super().request(**kwargs)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/requests/adapters.py:564, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     563 try:
# --> 564     resp = conn.urlopen(
#     565         method=request.method,
#     566         url=url,
#     567         body=request.body,
#     568         headers=request.headers,
#     569         redirect=False,
#     570         assert_same_host=False,
#     571         preload_content=False,
#     572         decode_content=False,
#     573         retries=self.max_retries,
#     574         timeout=timeout,
#     575         chunked=chunked,
#     576     )
#     578 except (ProtocolError, OSError) as err:
#     579     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.12.3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# document splitting

# %%
dataset_list
# Out:
# [Document(page_content='TAN TOCK SENG HOSPITAL PTE LTD,\nAddress : 11 Jalan Tan Tock Seng Singapore 308433,\nTelephone: 62566011,\nWebsite: https://www.ttsh.com.sg.\n\nTan Tock Seng Hospital (TTSH) is the \uf0dfagship hospital of NHG and part of Singapore’s public healthcare system. As a pioneering hospital with strong roots in the community for over 175 years, TTSH is recognised as the People’s Hospital, serving a resident population of 1.4 million living in Central Singapore.\nTogether, with 70 community partners and 80 community health posts, it brings care beyond the hospital into,\nthe community as an Integrated Care Organisation — Central Health.\nAs one of the largest multidisciplinary hospitals in Singapore, TTSH operates more than 1,700 beds,\nwith centres of excellence including the National Centre for Infectious Diseases (NCID), Institute for Geriatrics & Active Ageing (IGA), NHG Eye Institute (NHGEI), TTSH Rehabilitation Centre, and Ang Mo Kio Specialist Centre (AMKSC).\nTTSH’s 600-bed Integrated Care Hub will be ready in 2023 to provide for sub-acute care and rehabilitation.\nAs a healthcare leader in population health, systems innovation, health technologies and workforce transformation, TTSH hosts Singapore’s largest purpose- built innovation centre for healthcare — the Ng Teng Fong Centre for Healthcare Innovation (CHI) and its Co- Learning Network of 37 local and international partners.', metadata={'name': 'homepage', 'source': 'https://corp.nhg.com.sg/Pages/Digital%20Version%202022-2023/directory.pdf'}),
#  Document(page_content='Pharmacy,\nDRUG INFORMATION: Methotrexate,\nMethotrexate,\n- Methotrexate is an immunosuppressive drug which helps to control over- activity of the immune system by interfering with some actively growing cells within the body.\n- It is used for the treatment of various autoimmune diseases e.g. rheumatoid arthritis, Systemic Lupus Erythematosus (SLE), juvenile arthritis, psoriatic arthritis, and inflammatory myositis (muscle inflammation).\n- In arthritis, Methotrexate acts as a disease modifying anti-rheumatic drug (DMARD) to help to reduce pain, swelling and long-term joint damage.\n\nHow is Methotrexate Taken?\n- A typical weekly dose of Methotrexate ranges from 7.5mg to 25mg, given in the form of tablets or injection. Dosage may vary depending on your,\ndisease activity and response to the medicine.\n- It should be swallowed whole with a glass of water. Do not chew or crush the tablets. Wash hands thoroughly after administration.\n- Folic or folinic acid (also called folate) is often given with Methotrexate to reduce the risk of some side effects. It is usually taken a day before or,\nafter Methotrexate unless advised otherwise by your doctor.\n- The beneficial effects of Methotrexate will begin after 6 weeks and the full benefits may not be seen until after 12 weeks of treatment. Thus it is,\nimportant that you take your medication regularly, otherwise you may not benefit at all.\n- If you miss a dose, take it as soon as you remember if it is within 2 days from your scheduled dose. For example, your scheduled dose is on,\nSunday, if you remember on Tuesday, take the dose on Tuesday and resume back to the Sunday schedule the next week. Skip the dose if 3 or,\nmore days have lapsed since the missed dose. Do not double the dosage to make up for the missed dose.\n\nCan Methotrexate Be Taken with Other Medications?\n- Methotrexate can be taken with other medications such as corticosteroids, non-steroidal anti-inflammatory drugs (NSAIDs) and other disease modifying agents.\n- Please inform your doctor, pharmacist or rheumatology nurse clinician if you are taking other medications including over-the-counter medicines,,\nsupplements or traditional/herbal remedies as they may interact with Methotrexate.\n- Do not drink alcohol while on this medicine as it may increase the risk of liver toxicity associated with Methotrexate.\n- Pneumococcal and influenza (flu) vaccinations are safe and may be given if required. Avoid live vaccines such as MMR (measles, mumps and rubella), OPV (oral polio vaccine), yellow fever or BCG (tuberculosis). Discuss with your doctor before receiving any vaccines.\n\nWhat are the Important Side Effects of Methotrexate?\n- Many of the side effects occur at higher doses. Due to the way Methotrexate works, some side effects may be present only after years of taking this medication. Always discuss with your doctor if you experience any side effects.\nSIDE EFFECT AND MANAGEMENT,\nMouth ulcers: Folic/folinic acid can be prescribed to reduce this side effect.\nNausea, vomiting, diarrhoea or loss of appetite: Take medication after food to minimise the side effects. Folic/folinic acid can be prescribed to reduce this side effect. Alternatively, Methotrexate can be converted to an injection form. Consult your doctor immediately if you see bloody vomit or stools.\nSlow loss of hair: It is generally reversible when the medicine is discontinued.\nSkin rashes: These usually resolve readily upon decreasing the dose or stopping the medicine.\nLung inflammation (Warning signs: Persistent coughing, breathlessness or chest pain): Consult your doctor immediately. It is advisable to stop smoking.\nLiver disorder (Warning signs: Yellowing of eye whites or skin, dark or tea- coloured urine, or constant abdominal pain): Consult your doctor immediately. Avoid alcohol. Inform your doctor if you have any liver disease (e.g. jaundice, hepatitis) or if any of your family member has,\nhepatitis.\nBlood disorders (W ...
#  Document(page_content='Adrenaline auto-injector (EpiPen and EpiPen Jr),\nMedication Information Leaflet,\nWhat is this medication for?\n-\tThis medication contains epinephrine (or commonly known as adrenaline), which is used for the emergency treatment of sudden life-threatening allergic reactions (anaphylaxis).\n-\tSymptoms of allergic reactions include:,\n-\tMouth: itch and swelling of lips, tongue, or mouth,\n-\tThroat*: itching and/or a sense of tightness in the throat, hoarseness, hacking cough,\n-\tSkin: hives, itchy rash, and/or swelling on the face or extremities,\n-\tGut: nausea, abdominal cramps, vomiting, diarrhea,\n-\tLung*: shortness of breath, repetitive coughing and/or wheezing,\n-\tHeart*: passing out, fainting, dizziness,\n-\tThe severity of symptoms can quickly change. *All these symptoms can potentially progress to a life-threatening situation.\n\nHow should I take/use this medication?\nThere are two available strengths (EpiPen and EpiPen Jr), and the doctor will decide on the suitability according to your weight.\n1\tRemove auto-injector from the carrier tube.\n2\tHold the auto-injector with tip down.\n3\tMake a fist around the auto-injector.\n4\tPull off the blue safety release. Do not put your fingers or hand over the orange tip.\n5\tHold the auto-injector at a 90� angle to the outer thigh, Swing and firmly push the orange tip against the middle of the outer thigh, through clothing if needed.\n6\tIf you are administering EpiPen or EpiPen Jr to another person, hold the leg of the person firmly to prevent injury. Push the orange tip firmly against the middle of the outer thigh, through clothing if needed.\n7\tPress hard into the outer thigh until it clicks.\n8\tHold in place for 3 seconds then remove.\n9\tThe orange tip will extend to cover the needle.\n10\tMassage the area of injection for 10 seconds.\n11\tRecord the time the auto-injector was administered.\n12\tSeek medical help immediately, by reporting to your doctor or the nearest hospital, or call the local emergency response team (call 995 if in Singapore).\n13\tEffects of the auto-injector only last for 20-30 minutes.\n14\tIf your symptoms are still present 15 minutes after the first injection, you may need a second auto-injector.\n15\tThe auto-injector is for single use only.\n16\tSee your doctor for a refill or replacement of this medication.\n\nWhat should I do if I forget to take/use this medication?\n-\tSeek medical help immediately.\nWhat precautions should I take?\n-\tThere is no known reason why anyone should not use EpiPen or EpiPen Jr during life-threatening allergic reactions as they are critical for the treatment. However, inform your healthcare professional if you:,\n-\tHave heart conditions or high blood pressure,\n-\tHave diabetes,\n-\tHave thyroid conditions,\n-\tHave asthma,\n-\tHave a history of depression,\n-\tHave Parkinson\'s disease,\n-\tHave any other medical conditions,\n-\tAre allergic to this medication, sodium metabisulfite, or any of the other ingredients of this medication.\n-\tAre pregnant, planning to become pregnant, or breastfeeding.\n-\tCheck the "viewing window" to ensure that the solution is clear and colorless. If the "viewing window" is obscured, this means that the auto-injector has been used and cannot be used again. Replace the EpiPen or EpiPen Jr if the medication appears cloudy, contains particles, or changes color (from clear solution to pink or brown color).\n-\tAlways check the expiry date indicated on the label. Replace the EpiPen and EpiPen Jr if they have expired. Do not use them after the expiry date.\n-\tDo not inject this medication into your blood vessels, buttocks, fingers, toes, hands or feet. If you accidentally inject into any of these areas, go to the nearest emergency room immediately.\n-\tAlways carry this medication with you at all times.\n\nWhat are some common side-effects of this medication?\n-\tThese common side effects may disappear with rest. If any of the following effects persist  ...
#  Document(page_content='Folic Acid (Folate),\nMedication Information Leaflet,\nWhat is the medication used for?\nFolic acid (or folate) is a type of vitamin naturally found in some foods that helps the body to produce red blood cells. A lack of folic acid may result in folate-deficiency anemia, a condition in which there is insufficient healthy red blood cells to provide oxygen to the body.\nDuring pregnancy, folic acid supplementation may reduce the incidence of birth defects (e.g., abnormal development of brain and spinal cord in the baby).\nFolic acid supplementation may be required in those with certain conditions (e.g., kidney disease, excessive alcohol intake) or taking certain medications (e.g., Methotrexate, Sulfasalazine).\n\nHow should I take/use the medication?\n-\tDo not stop taking your medications without checking with your healthcare professional.\n-\tThis medication may be taken with or without food.\nWhat should I do if I forget to take/use this medication?\nIf you miss a dose, take the missed dose as soon as you remember. If it is almost time for your next dose, take only the usual dose. Do not double your dose or use extra medication to make up for the missed dose.\n\nWhat precautions should I follow when taking the medication?\nInform your healthcare professional if:,\n-\tYou are allergic to this medication, or any of the other ingredients in this medication.\n-\tYou are taking any other medications, including supplements, traditional medications, and herbal remedies.\nWhat are some common side-effects of this medication?\nGenerally, this medication is well tolerated without any significant side effects.\n\nWhat are some rare but serious side-effects that I need to seek medical advice immediately?\nThe symptoms of a drug allergy include one or more of the following:,\n-\tSwollen face/eyes/lips/tongue,\n-\tDifficulty in breathing,\n-\tItchy skin rashes over your whole body,\nIf you experience any of these symptoms, you should stop your medication and see your healthcare professional immediately.\n\nHow should I store the medication?\nStore in a cool and dry place, away from direct sunlight. Keep this medication away from children. Throw away all expired medications.\nHow should I throw away this medication safely?\nPack this medication into a black trash bag and seal it tightly before throwing it into the rubbish chute or bin.\n\nDisclaimers,\nPlease take note that the above is not a complete list of all possible side effects. If you have any concerns about your medication or if you have other side effects that you think are caused by this medication, please consult your doctor or pharmacist.\nIf you take more than the recommended dose, please seek medical advice immediately. The information provided on this page does not replace information from your healthcare professional. Please consult your healthcare professional for more information.\nThis transcription captures the key details and instructions provided in the medication leaflet for Folic Acid, focusing on its uses, dosing instructions, potential side effects, and other important precautions.', metadata={'name': 'folate', 'source': 'https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Documents/Pharmacy/PIL/PIL_by_Drug/Folic_Acid.pdf'}),
#  Document(page_content="What is ibuprofen?\nIbuprofen is a type of anti-inflammatory pain-relief medicine that treats fever and mild to moderate pain caused by inflammation. It belongs to a group of medicines called non-steroidal anti-inflammatory drugs, or NSAIDs.\nHow does ibuprofen work?\nIbuprofen works on one of the body's chemical pathways for pain. It reduces your body's ability to make prostaglandins - these are the natural chemicals that trigger pain, inflammation and fever.\nWith fewer prostaglandins in your body, pain and inflammation are reduced, and your fever goes down.\n\nWhat is ibuprofen used for?\nIbuprofen can be used for the short-term relief of fever, mild to moderate pain and inflammation (redness, swelling and soreness).\nIbuprofen might also reduce some of the symptoms of:,\nheadaches (including migraines or tension headache),\nsinus pain,\ntoothache and pain after dental procedures,\nbackache and muscular aches and pains,\nperiod pain,\nsore throat,\narthritis,\nIbuprofen provides only temporary relief - it won't cure your condition.\n\nWhat are the possible side effects of ibuprofen?\nCommon side effects of ibuprofen include:,\nupset stomach e.g. nausea, diarrhoea and indigestion,\nheadache,\ndizziness,\nhigh blood pressure,\nfluid retention.\n\nSerious side effects of ibuprofen that need immediate medical attention include:,\nasthma, wheezing and shortness of breath,\nswelling of the face, lips or tongue, which may cause difficulty breathing or swallowing,\ndark vomit that looks like coffee grounds,\nblack stools that can indicate bleeding,\nThis is not a full list of side effects. For more information, talk to your doctor or pharmacist or check the consumer medicine information leaflet in your medicine packaging.\nThe dose of ibuprofen will be printed on the package. Do not take more than the maximal daily dose.\n\nAre there alternatives to ibuprofen?\nIf you're treating fever or mild to moderate pain, ask your pharmacist if you can use paracetamol in place of ibuprofen.\n\nFor pain or inflammation-related swelling, ask your doctor or pharmacist for another option if ibuprofen is not suitable for you. Your health professional may suggest you try:,\nparacetamol,\nanother medicine from the NSAID family,\na medicine that combines codeine with paracetamol or ibuprofen in the same tablet,\nIf your pain is severe, your doctor may prescribe you a stronger pain reliever.", metadata={'name': 'ibuprofen', 'source': 'https://www.healthdirect.gov.au/ibuprofen'}),
#  Document(page_content='Prescription Refill,\nTTSH Medication Delivery Service.\n\nPillDeliver,\nReceive your medication at the address provided.\nYou will receive an SMS containing the PIN code for your medication delivery on the day of delivery. Please ensure that someone is at the delivery address during the delivery timeslot. (Note: Medication parcels cannot be left unattended at the riser/doorstep). Quote the PIN code in the SMS to the delivery courier to receive your medication.\nThe following timeslots are available for PillDeliver:,\n9am - 1pm: Weekdays, Saturdays,\n2pm - 6pm: Weekdays, Saturdays,\n7pm - 10pm: Weekdays.\n\nPillLocker,\nCollect your medication within 3 calendar days of receiving an SMS notification.\nPillLocker locations: https://www.ttsh.com.sg/Patients-and-Visitors/Medical-Services/Pharmacy/Medication-Delivery-Service/Pages/PillLocker.aspx,\nHow do I refill my prescription?\nPlease order at least 2 weeks in advance so that we can process your request.\nYou can order via:,\n1\tFormSG: https://www.form.gov.sg/604707a64f1157001163e759,\n2\tHealthHub > Personal Health > Medication Refill,\n3\tPharmEzy Website: Prescription Refill,\n4\tPhone call: 63572050, from 9.30am - 5.30pm, Mondays to Fridays (excluding Saturday and Sunday, Public Holidays and eve of Public Holidays).\n', metadata={'name': 'prescriptionrefill', 'source': 'https://www.ttshpharmezy.nhg.com.sg/prescription'}),
#  Document(page_content='Appointments,\nRequest appointment,\n-\tIf you have a referral from a polyclinic doctor and do not choose your specialist doctor at our SOC, you can enjoy subsidy from the Government for your consultation and treatment.\n-\tPlease note that as a government-patient, you may be seen by subsidised different doctors during the course of your treatment. The polyclinic will usually make a specialist appointment on your behalf.\n-\tIf you have been seen by our Emergency Department doctors or are discharged from our hospital and needs specialist consultation, we will arrange and advise you on your SOC appointment.\n-\tConsultation at our Specialist Outpatient Clinics (SOC) and treatment by our Allied Health Services is by appointment only.\n-\tYou can call us directly or your general practitioner/family doctor can help to make the arrangement for you.\n-\tNotice: If it is a medical emergency, please call for an SCDF ambulance at 995 or go to our Emergency Department for medical attention.\n-\tWhat should I bring?\n-\tOn your first visit to the specialist clinic, please bring the following documents for registration:,\n-\tPersonal documents,\n-\tNRIC,\n?\tBirth Certificate (if you are below 12 years old),\n?\tPassport,\n?\tEmployment Pass/ Work Permit,\n-\tReferral letter (if any),\n-\tAny medical benefit identification documents (e.g. Civil Service Card, Medical Benefits Card, etc),\n-\tUpdate or cancel appointment,\n-\tTo cancel or update your appointment, please call 6357 7000 or email Contact@ttsh.com.sg . Calls are available during these times Mondays to Fridays 8.00 am to 5.00 and Saturdays 8.00 am to 12.00 pm.\n-\tYou may download HealthHub app to access health information and services conveniently from your mobile device.\n', metadata={'name': 'appointment', 'source': 'https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx'}),
#  Document(page_content="Department of,\nRHEUMATOLOGY, ALLERGY AND IMMUNOLOGY,\nRheumatoid Arthritis,\nClinics B1A and B1B,\nTTSH Medical Centre, Level B1,\nContact: 6357 7000 (Central Hotline).\n\nWhat is Rheumatoid Arthritis?\nRheumatoid arthritis (RA) is an autoimmune disease that causes chronic inflammatory arthritis (warm, swollen, painful joints) and may affect other parts of the body including the eyes, lungs, skin, heart, blood vessels and nerves.\n\nWho are at Risk of RA?\nRA is more common in women. It usually occurs in people aged between 25 to 50 years old, but young children and elderly may be affected too.\n\nWhat Causes RA?\nThe precise cause of RA is unknown. It is likely to be caused by a combination of factors like:,\n-\tGenetics�,\n-\tAbnormal immune system�,\n-\tEnvironment (e.g. smoking, stress)�,\n-\tHormones.\n\nSymptoms and Signs of RA,\nIn early stages of RA, most people experience:�,\n-\tEarly morning stiffness�,\n-\tAching of the joints,\n(especially in hands and feet)�,\n-\tFatigue,\nOvertime, the joints become warm, painful and swollen. The same joints on both sides of the body tend to be affected, especially the hands and feet.\nPeople with RA may also:�,\n-\tLose their appetite�,\n-\tLose weight�,\n-\tDevelop depression�,\n-\tExperience general tiredness and fatigue (dependant on the amount of inflammation the patient has),\nEarly diagnosis can prevent irreversible joint damage and preserve joint function.�.\n\nHow is RA Diagnosed?\nRA is diagnosed based on,\nhistory, physical examination and laboratory tests.\nImaging may be required if RA is in its early stages or symptoms and signs appear unusual.\nThe doctor may also drain fluid from your joints to ensure your arthritis is not due to an infection or some other causes.\nYour doctor may perform a biopsy to remove small bits of inflamed joint tissue or nodules for examination only when needed.\nCommon tests performed for RA patients,\ninclude:,\n- Full blood count,\n- Kidney function and liver function tests - Inflammatory markers tests,\n- Auto-antibodies tests,\n- X-Rays of affected joints.\n\nWhat are the Treatments for RA?\n1. Patient Education,\nThis consists of empowering yourself with knowledge and taking charge of your health.\nAdvice includes:,\n- Learn as much as you can about RA.\n- Do not be afraid of arthritis. Most patients,\nwith RA lead normal lives.\n- Seek your doctor's advice early.\nAvoid unnecessary strain on affected joints.\n- Take medications as advised by your doctor.\n- Do not change the dosage or types of medication without your doctor's knowledge.\n- Do not rely on unproven remedies in hope that the disease will go away.\n- Do not change doctor unnecessarily because the treatment of RA is complex and long-term. It is best that you build a lasting relationship with your doctor.\n- Get adequate rest and sleep.\n- Join support groups like the National Arthritis Foundation. Scan the QR code below or access https://naf.org.sg/naf- membership-signup/ to join!\n2. Medication,\nMajority of patients with RA require medications.\n- Non-Steroidal Anti-inflammatory Drugs (NSAIDs),\nUsually used to reduce joint swelling, pain and stiffness.\n- Disease Modifying Anti-rheumatic Drugs (DMARDs),\nAims to suppress inflammation so that joint pain and swelling are controlled and damage to joints is minimised.\nCorticosteroids,\nOften used in low doses in combination with NSAIDs and DMARDs to enable quick control of inflammation.\n3\tPhysiotherapy (PT) and Occupational Therapy (OT),\nImprove pain control using non- pharmacological methods,\n(e.g. heat and cold therapy).\nExplore ways of improving mobility of injured joints and muscles (e.g. application of splints).�,\n4\tBiologics Agents,\nThey are medical products extracted or produced from biological sources. They are expensive and reserved for arthritis that is not controlled by standard therapy.�,\n5\tLifestyle Modification,\nQuit smoking, have adequate rest, exercise and maintain idea ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=50) #how to make splitting better semantically?
texts = text_splitter.split_documents(dataset_list)
#get page_content from each text

# %%
print(texts[0])
# Out:
# page_content='TAN TOCK SENG HOSPITAL PTE LTD,\nAddress : 11 Jalan Tan Tock Seng Singapore 308433,\nTelephone: 62566011,\nWebsite: https://www.ttsh.com.sg.' metadata={'name': 'homepage', 'source': 'https://corp.nhg.com.sg/Pages/Digital%20Version%202022-2023/directory.pdf'}

# %%
client.connections.get_details(connection_id='0cb5aa86-1899-4e66-83f3-89e5d8dd0a93')
# Out:
# {'metadata': {'id': '0cb5aa86-1899-4e66-83f3-89e5d8dd0a93',
#   'asset_type': 'connection',
#   'create_time': '2024-05-30T02:59:39.000Z',
#   'last_access_time': '2024-06-03T03:29:27.241Z',
#   'project_id': '7e0c4482-de51-45d1-a85d-2bc5d0aa5003'},
#  'entity': {'datasource_type': '193a97c1-4475-4a19-b90c-295c4fdc6517',
#   'name': 'CloudObjectStorage',
#   'origin_country': 'us',
#   'owner_id': 'IBMid-698000DX9C',
#   'properties': {'bucket': '10be7d6b-6c04-469f-83a8-18aad81af8bd',
#    'trust_all_ssl_cert': 'false',
#    'auth_method': 'instanceid_apikey',
#    'iam_url': 'https://iam.cloud.ibm.com/identity/token',
#    'api_key': 'OUesIzDT8u0tULKu_QQUX3V7zkqsvjDiuhws6KlU-0g_',
#    'resource_instance_id': '41fbacf2-83e0-420e-9d15-4f332ba94e85',
#    'url': 'https://s3.us-south.cloud-object-storage.appdomain.cloud'}}}

# %%
esuser = 'ibm_cloud_47c1b265_9888_496c_81f5_bc5f27cd8de6'
espassword = '8d6945e362751bfa31c274366283e2004ce3fb3894f169933722cb72d80b7ca0'
eshost = '48e50692-4d3c-488f-b7a2-9c87ab7d1ffb.c5kn1n9d0g7polghe820.databases.appdomain.cloud'
esport = '31496'
es_ssl_fingerprint = !openssl s_client -connect $eshost:$esport  -showcerts </dev/null 2>/dev/null | openssl x509 -fingerprint -sha256 -noout -in /dev/stdin
es_ssl_fingerprint = es_ssl_fingerprint[0].split("=")[1]
from elasticsearch import Elasticsearch

es_client = Elasticsearch(
    f'https://{eshost}:{esport}',
    basic_auth=(esuser, espassword),
    verify_certs=False,
    request_timeout=3600,
    ssl_assert_fingerprint=es_ssl_fingerprint
)
es_client.info()
# Out:
# ObjectApiResponse({'name': 'm-1.48e50692-4d3c-488f-b7a2-9c87ab7d1ffb.e33cad83d5c04fbb91981c6744a2695a.c5kn1n9d0g7polghe820.databases.appdomain.cloud', 'cluster_name': '48e50692-4d3c-488f-b7a2-9c87ab7d1ffb', 'cluster_uuid': 'o5PZ7dGeR_6QMICzRs77jg', 'version': {'number': '8.12.1', 'build_flavor': 'default', 'build_type': 'tar', 'build_hash': '6185ba65d27469afabc9bc951cded6c17c21e3f3', 'build_date': '2024-02-01T13:07:13.727175297Z', 'build_snapshot': False, 'lucene_version': '9.9.2', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
model_id = '.elser_model_2'
model_schema = {"input": {"field_names": ['text']}}
es_client.ml.get_trained_models(
            model_id='.elser_model_2')

deployment_id = model_id
existing_deployments = (
    es_client.ml.get_trained_models_stats(model_id=model_id)
    .body["trained_model_stats"][0]
    .get("deployment_stats")
)
if (
    existing_deployments
    and existing_deployments.get("deployment_id") == deployment_id
):
    print(f"{model_id} model deployment with the same name already exists.")
else:
    print(
        f"Creating {model_id} model deployment with deployment id {deployment_id}..."
    )
    es_client.ml.start_trained_model_deployment(
        model_id=model_id, deployment_id=deployment_id
    )

# es_client.ingest.put_pipeline(
#     id='elser-ingest-pipeline',
#     processors=[
#         {
#             'inference': {
#                 'model_id': model_id,
#                 'input_output': [
#                     {
#                         'input_field': 'text',
#                         'output_field': 'elser_embedding',
#                     }
#                 ]
#             }
#         }
#     ]
# )
# try:
#     es_client.indices.delete(index='my_documents', ignore_unavailable=True)
#     es_client.indices.create(
#             index='my_documents',
#             mappings={
#                 'properties': {
#                     'embedding': {
#                         'type': 'dense_vector',
#                     },
#                     'elser_embedding': {
#                         'type': 'sparse_vector',
#                     },
#                 }
#             },
#             settings={
#                 'index': {
#                     'default_pipeline': 'elser-ingest-pipeline'
#                 }
#             }
#         )
#     print("Index created successfully.")
# except:
#     print("Index already exists.")


# operations = []
# for document in documents:
#     operations.append({'index': {'_index': 'my_documents'}})
#     operations.append({'text': document})
# es_client.bulk(operations=operations, index='my_documents', pipeline='elser-ingest-pipeline', refresh=True)


# print("Document ingested successfully.")
# Out:
# .elser_model_2 model deployment with the same name already exists.

# %%
es_client.ingest.put_pipeline(
    id='elser-ingest-pipeline',
    processors=[
        {
            'inference': {
                'model_id': model_id,
                'input_output': [
                    {
                        'input_field': 'page_content',
                        'output_field': 'elser_embedding',
                    }
                ]
            }
        }
    ]
)
try:
    es_client.indices.delete(index='my_documents1', ignore_unavailable=True)
    es_client.indices.create(
        index='my_documents1',
        body={
            'mappings': {
                'properties': {
                    'embedding': {
                        'type': 'dense_vector',
                    },
                    'elser_embedding': {
                        'type': 'sparse_vector',
                    },
                    'metadata': {
                        'properties': {
                            'name': {
                                'type': 'keyword'
                            },
                            'source': {
                                'type': 'keyword'
                            }
                        }
                    }
                }
            },
            'settings': {
                'index': {
                    'default_pipeline': 'elser-ingest-pipeline'
                }
            }
        }
    )
    print("Index created successfully.")
except Exception as e:
    print(f"Error creating index: {e}")


# Prepare the bulk indexing operations
operations = []
for doc in texts:
    operations.append({'index': {'_index': 'my_documents1'}})
    operations.append({
        'page_content': doc.page_content,
        'metadata': doc.metadata
    })

# Perform the bulk indexing
es_client.bulk(operations=operations, index='my_documents1', pipeline='elser-ingest-pipeline', refresh=True)
# Out:
# Index created successfully.
# ObjectApiResponse({'errors': False, 'took': 278, 'ingest_took': 1824, 'items': [{'index': {'_index': 'my_documents1', '_id': '-3W1_I8BAfgBwTpNyj-8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 0, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': '_HW1_I8BAfgBwTpNyj-8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 1, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': '_XW1_I8BAfgBwTpNyj-8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 2, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': '_nW1_I8BAfgBwTpNyj-8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 3, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': '_3W1_I8BAfgBwTpNyj-8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 4, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'AHW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'AXW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 6, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'AnW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 7, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'A3W1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 8, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'BHW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 9, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'BXW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 10, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'BnW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 11, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'B3W1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 12, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'CHW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 13, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'CXW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 14, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'CnW1_I8BAfgBwTpNykC8', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 15, '_primary_term': 1, 'status': 201}}, {'index': {'_index': 'my_documents1', '_id': 'C3W1_I8BAfgBwTpNykC9', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, ' ...

# %%
parsed_query = "how do i book an appointment?"
response = es_client.search(
        index='my_documents1', 
        body={
            'query': {
                'bool': {
                    'must': [
                        {
                            'text_expansion': {
                                'elser_embedding': {
                                    'model_id': '.elser_model_2',
                                    'model_text': parsed_query,
                                }
                            },
                        }
                    ],
                }
            },
            'aggs': {
                'category-agg': {
                    'terms': {
                        'field': 'category.keyword',
                    }
                },
            },
            'size': 5,
            "min_score": 8 ,
        },
        
)

# %%
response.body
# Out:
# {'took': 25,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 2, 'relation': 'eq'},
#   'max_score': 12.266482,
#   'hits': [{'_index': 'my_documents1',
#     '_id': 'OHW1_I8BAfgBwTpNykC9',
#     '_score': 12.266482,
#     '_ignored': ['page_content.keyword'],
#     '_source': {'elser_embedding': {'cancel': 1.5640881,
#       '00': 0.20025246,
#       '##b': 1.0955287,
#       'weekends': 0.26215824,
#       '03': 0.025296943,
#       'pt': 0.18588853,
#       '##h': 0.817397,
#       'bring': 0.19405667,
#       'your': 0.07379847,
#       '##p': 0.0504971,
#       'identification': 0.9596832,
#       'jan': 0.48785138,
#       'pension': 0.03968984,
#       'zealand': 0.62268114,
#       'tel': 0.2840549,
#       'welcome': 0.14226456,
#       'mauritius': 0.68640035,
#       'app': 0.78509635,
#       'appointments': 0.9720861,
#       'australia': 0.38164002,
#       'benefit': 1.1089985,
#       'morning': 0.08472396,
#       'badge': 0.22395556,
#       'cancellation': 1.0229297,
#       '5': 0.20112656,
#       'doctors': 0.07156081,
#       'letter': 1.002945,
#       '7': 0.06569293,
#       '8': 0.5917111,
#       'zulu': 0.55004567,
#       '@': 0.8095332,
#       'bc': 0.021953074,
#       'saturday': 1.2389256,
#       '##ral': 1.4009808,
#       'access': 0.76045465,
#       'document': 0.8925691,
#       'availability': 0.49732774,
#       'sa': 0.75938493,
#       'weekly': 0.22361074,
#       'kenya': 0.0886385,
#       'referring': 0.15146463,
#       'sg': 1.504259,
#       'civil': 0.8140733,
#       'email': 0.7439064,
#       'latest': 0.0884983,
#       'ss': 0.13609652,
#       'website': 0.4485835,
#       'address': 0.22325721,
#       'renewal': 0.18777958,
#       'thursday': 0.9631085,
#       'staff': 0.19586228,
#       'union': 0.4634037,
#       'procedure': 0.1746291,
#       'services': 0.17442107,
#       'ta': 0.6390171,
#       'call': 1.3107882,
#       'td': 0.746888,
#       't': 0.92250866,
#       'prayer': 0.20614833,
#       'calls': 0.58668756,
#       '700': 1.0627359,
#       'information': 0.62605745,
#       'interview': 0.030394394,
#       'open': 0.3998406,
#       'contacts': 0.03533724,
#       'ts': 0.082289204,
#       'surgery': 0.005565505,
#       'tt': 1.916411,
#       'insurance': 0.41390738,
#       'tu': 0.20384994,
#       'medical': 1.1975306,
#       'till': 0.15471594,
#       'dh': 0.06806404,
#       'documents': 0.901166,
#       'available': 0.83128947,
#       'numbers': 0.1639495,
#       'emergency': 0.36017427,
#       'secure': 0.0037174185,
#       'dr': 0.07510555,
#       'scotland': 0.024028752,
#       'jamaica': 0.36822295,
#       'passport': 0.24425165,
#       'leave': 0.0321963,
#       'contact': 0.88759464,
#       'thailand': 0.5133419,
#       'minister': 0.10812403,
#       '##sh': 1.7351097,
#       'saturdays': 1.2813348,
#       'need': 0.043083955,
#       'pay': 0.22357777,
#       'lanka': 0.023955313,
#       'korea': 0.12736528,
#       'volunteer': 0.038162477,
#       'fa': 0.027618064,
#       '63': 1.1996055,
#       'benefits': 0.66173226,
#       'submit': 0.15364708,
#       'android': 0.2124944,
#       'update': 0.99414635,
#       'malaysia': 0.66109693,
#       'india': 0.28305876,
#       'mondays': 1.4255177,
#       'papers': 0.19062227,
#       'fridays': 1.0691057,
#       'button': 0.081403114,
#       '##ss': 0.025094563,
#       'provider': 0.5350423,
#       'jersey': 0.40752593,
#       'sim': 0.1476912,
#       'wai': 0.25511652,
#       'hours': 0.9775059,
#       'ticket': 0.36103663,
#       'mobile': 1.022024,
#       'home': 0.08726959,
#       'schedule': 0.41725162,
#       'form': 0.38983777,
#       'refer': 1.3131492,
#       'complaint': 0.2038832,
#       'service': 0.40632892,
#       'time': 0.38411412,
#       'renew': 0.18061605,
#       'medicare': 0.6190681,
#       'software': 0.016119983,
#       'eligibility': 0.10901285,
#       'during': 0.06552581,
#       'hu': 0.566141,
#       'number': 1.1203183,
#       '##57': 0.11764103,
#       'id': 0.52379453,
#       'portal': 0.3038927,
#       'order': 0.25443304,
#       'africa': 0.21610215,
#       'certification': 0.114014864,
#       'sunday': 0.6099254,
#       'phone': 1.1465812,
#       'cancelled': 0.55976963,
#       'doc': 0.021643398,
#       'registration': 0.46017528,
#       'card': 0.83717585,
#       'care': 0.3531452,
#       'denial': 0.05653578,
#       'wait': 0.2928648,
#       'south': 0.24936868,
#       'weekend': 0.08764205,
#       'paperwork': 0.56299365,
#       'healthcare': 0.31198707,
#       'file': 0.029984828,
#       'web': 0.11222529,
#       'transplant': 0.13706613,
#       'monday': 1.3297037,
#       'nigeria': 0.34827334,
#       'change': 0.3492719,
#       'health': 1.1141021,
#       'fiji': 0.6193154,
#       'singapore': 1.3873566,
#       'prescription': 0.16888668,
#       '##ho': 0.3754657,
#       '##hu': 1.8135908,
#       'board': 0.1446376,
#       'indian': 0.13775626,
#       'residency': 0.3615419,
#       'mail': 0.52663505,
#       'disability': 0.21343654,
#       'pakistan': 0.5579417,
#       'appointment': 1.4978707,
#       'office': 0.7343285,
#       'employee': 0.12861565,
#       'reference': 0.17075634,
#       'heath': 0.08140729,
#       'download': 0.73689693,
#       'karen': 0.08155431,
#       'tab': 0.027226847,
#       'etc': 0.19981924,
#       'md': 0.07199541,
#       'entrance': 0.069293424,
#       'tanzania': 0.6787978,
#       'tam': 0.22212155,
#       'mp': 0.32916805,
#       'diagnosis': 0.13082798,
#       'thai': 0.84788,
#       'clock': 0.6156913,
#       'my': 0.017506365,
#       'convenient': 0.36716375,
#       'request': 0.070850745,
#       'np': 0.0779347,
#       'code': 0.8404816,
#       'week': 0.4888576,
#       'burma': 0.43457264,
#       'med': 0.16711849,
#       'times': 0.4560321,
#       'hour': 0.48866126,
#       'patient': 0.4999655,
#       'russ': 0.27494568,
#       'today': 0.13435502,
#       'friday': 1.4071845,
#       'sai': 0.071101144,
#       'hospital': 0.66077507,
#       '##ish': 0.34642226,
#       'myanmar': 0.30859372,
#       'transport': 0.0015201928,
#       'rush': 0.08580669,
#       'doctor': 0.70584357,
#       'tuesday': 0.5297978,
#       'application': 0.36813518,
#       'nhs': 0.27608076,
#       'online': 0.5339876,
#       'clinic': 0.9316413,
#       'visit': 0.56498146,
#       'pm': 0.63811153,
#       'maintenance': 0.28282017,
#       'forms': 0.16157994},
#      'metadata': {'name': 'appointment',
#       'source': 'https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx'},
#      'page_content': '-\tReferral letter (if any),\n-\tAny medical benefit identification documents (e.g. Civil Service Card, Medical Benefits Card, etc),\n-\tUpdate or cancel appointment,\n-\tTo cancel or update your appointment, please call 6357 7000 or email Contact@ttsh.com.sg . Calls are available during these times Mondays to Fridays 8.00 am to 5.00 and Saturdays 8.00 am to 12.00 pm.\n-\tYou may download HealthHub app to access health information and services conveniently from your mobile device.',
#      'model_id': '.elser_model_2'}},
#    {'_index': 'my_documents1',
#     '_id': 'NnW1_I8BAfgBwTpNykC9',
#     '_score': 8.139514,
#     '_ignored': ['page_content.keyword'],
#     '_source': {'elser_embedding': {'expert': 0.45915666,
#       'practice': 0.0697995,
#       'during': 0.015858948,
#       'your': 0.0029192236,
#       'hem': 0.025107004,
#       'discharged': 1.1515093,
#       'arranging': 0.2841372,
#       'injury': 0.29712552,
#       'arrangements': 0.30920205,
#       'welcome': 0.24970965,
#       'you': 0.054564036,
#       'aa': 0.070842974,
#       'glasgow': 0.13406837,
#       'appointments': 0.6650836,
#       'practitioner': 0.85323846,
#       'in': 0.021740336,
#       'ambulance': 0.64889574,
#       'allied': 1.9010464,
#       'iv': 0.04511035,
#       'panic': 0.15706688,
#       'exam': 0.099512264,
#       'sydney': 0.22811858,
#       'practitioners': 0.45169663,
#       'at': 0.13568485,
#       'phone': 0.38586915,
#       'doctors': 0.97959805,
#       'funeral': 0.1763398,
#       'doc': 0.1893755,
#       'consultation': 1.3378751,
#       'allies': 0.0806701,
#       'care': 0.36693713,
#       'cardiac': 0.067567445,
#       'treatment': 0.9450853,
#       'other': 0.04411791,
#       'toronto': 0.021082938,
#       'direct': 0.019467948,
#       'ward': 0.48984194,
#       'our': 0.8128258,
#       'seen': 0.5532667,
#       'accident': 0.35647577,
#       'bp': 0.16924302,
#       'sa': 0.044933025,
#       'out': 0.9736024,
#       'see': 0.23517802,
#       'nurse': 0.3206759,
#       'transplant': 0.30842593,
#       'physician': 0.32916403,
#       'consult': 0.030571887,
#       'departments': 0.084100455,
#       'urgent': 0.14959802,
#       '##patient': 1.2883427,
#       'consulting': 0.24902369,
#       'health': 0.58543456,
#       'medicine': 0.2591609,
#       'specialists': 0.8280138,
#       'services': 0.7157468,
#       'procedure': 0.1420351,
#       'team': 0.039139863,
#       'cp': 0.060621705,
#       'call': 0.77862376,
#       'ct': 0.23441875,
#       'help': 0.16499145,
#       'consultant': 0.5141356,
#       'partner': 0.14571047,
#       'prescription': 0.07033621,
#       'appoint': 0.08726719,
#       'ask': 0.041551024,
#       'interview': 0.24354455,
#       'experts': 0.06595523,
#       'surgery': 0.4864741,
#       'hospitals': 0.54566395,
#       'medical': 0.66110736,
#       'soc': 2.2601314,
#       'officer': 0.06444324,
#       'emergency': 1.6877493,
#       'appointment': 1.1782968,
#       'specialised': 0.57602316,
#       'office': 0.07675608,
#       'dr': 0.07922394,
#       'pediatric': 0.35056207,
#       'arrangement': 0.92164016,
#       'heath': 0.1690086,
#       'arrange': 0.97092175,
#       'uk': 0.13321106,
#       'contact': 0.4392351,
#       'discharge': 1.1661019,
#       'only': 0.6944423,
#       'from': 0.24806084,
#       'directly': 0.3586476,
#       'ed': 0.18612675,
#       'needs': 0.20233549,
#       'chest': 0.26823607,
#       'crisis': 0.030295286,
#       'need': 0.608115,
#       'intra': 0.21652302,
#       'mr': 0.11695755,
#       'ek': 0.45854896,
#       'patients': 0.17011939,
#       'er': 0.7280876,
#       'campbell': 0.03503283,
#       'ama': 0.049616523,
#       'specialist': 1.5865462,
#       'outside': 0.057404663,
#       'specialized': 0.7507957,
#       'clinics': 1.1771183,
#       'advice': 0.8042451,
#       'recovery': 0.07649694,
#       'sic': 0.46220753,
#       'med': 0.21201138,
#       'levy': 0.40780902,
#       'we': 0.2973878,
#       'sid': 0.035234362,
#       'general': 0.8176772,
#       'wound': 0.13277137,
#       'arranged': 0.68783766,
#       'ally': 0.7326713,
#       'provider': 0.22400568,
#       'patient': 0.84282094,
#       'advise': 0.5663402,
#       'hospital': 1.0909073,
#       'department': 0.8603849,
#       'rescue': 0.273457,
#       'will': 0.13550498,
#       'therapy': 0.24728502,
#       'saw': 0.031731114,
#       'gp': 0.15053114,
#       'solo': 0.43689814,
#       'doctor': 0.842898,
#       'special': 0.039833043,
#       'schedule': 0.03655693,
#       'service': 0.29236507,
#       'nhs': 0.3477898,
#       'jason': 0.002006186,
#       'online': 0.14105052,
#       'clinic': 1.2604241,
#       'visit': 0.4498484,
#       'family': 0.6429878},
#      'metadata': {'name': 'appointment',
#       'source': 'https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx'},
#      'page_content': '-\tIf you have been seen by our Emergency Department doctors or are discharged from our hospital and needs specialist consultation, we will arrange and advise you on your SOC appointment.\n-\tConsultation at our Specialist Outpatient Clinics (SOC) and treatment by our Allied Health Services is by appointment only.\n-\tYou can call us directly or your general practitioner/family doctor can help to make the arrangement for you.',
#      'model_id': '.elser_model_2'}}]},
#  'aggregations': {'category-agg': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': []}}}

# %%
for i in response.get('hits').get('hits'):
    print(i.get('_source').get('page_content'))
    print(i.get('_source').get('metadata')['source'])
    print('---')
    i.append(list(rag_info[0]+"\nSource:\n"+rag_info[1]))
# Out:
# -	Referral letter (if any),
# -	Any medical benefit identification documents (e.g. Civil Service Card, Medical Benefits Card, etc),
# -	Update or cancel appointment,
# -	To cancel or update your appointment, please call 6357 7000 or email Contact@ttsh.com.sg . Calls are available during these times Mondays to Fridays 8.00 am to 5.00 and Saturdays 8.00 am to 12.00 pm.
# -	You may download HealthHub app to access health information and services conveniently from your mobile device.
# https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx
# ---
# -	If you have been seen by our Emergency Department doctors or are discharged from our hospital and needs specialist consultation, we will arrange and advise you on your SOC appointment.
# -	Consultation at our Specialist Outpatient Clinics (SOC) and treatment by our Allied Health Services is by appointment only.
# -	You can call us directly or your general practitioner/family doctor can help to make the arrangement for you.
# https://www.ttsh.com.sg/Patients-and-Visitors/Your-Clinic-Visit/Pages/Appointments.aspx
# ---

# %%
# import pandas as pd
# import re
# import json

# df = pd.read_csv('medDataset_processed.csv')
# # Assuming df has 'Input' and 'Output' columns

# # Randomly select 10000 rows
# df = df.sample(n=10000, random_state=1)  # using random_state for reproducibility

# # Drop index
# df = df.reset_index(drop=True)

# # Drop NA values
# df = df.dropna()

# # Drop duplicates
# df = df.drop_duplicates()

# # Drop rows with empty strings
# df = df[(df['input'] != '') & (df['output'] != '')]

# # Check characters are identifiable
# df = df[df['input'].apply(lambda x: all(char.isprintable() for char in x))]

# # Check characters are letters, numbers, punctuation, whitespace or \n only
# pattern = re.compile(r'^[\w\s.,;:!?()\"\'\-\n]+$')

# def check_characters(text):
#     return bool(pattern.match(text))

# df = df[df['input'].apply(check_characters)]

# # Convert the DataFrame to a list of dictionaries
# data = df.to_dict(orient='records')

# # Save the list of dictionaries as a JSON file
# with open('medDataset_processed.json', 'w') as f:
#     json.dump(data, f, indent=2)

# print("JSON file created successfully.")
# Out:
# JSON file created successfully.

# %%
from ibmcloudant.cloudant_v1 import CloudantV1, Document
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_cloud_sdk_core import ApiException

import os
from dotenv import load_dotenv
load_dotenv()
IBM_CLOUD_APIKEY = os.getenv("IBM_CLOUD_APIKEY")
url = "https://c9a324f3-322e-48a0-a1d0-7d68af81c27d-bluemix.cloudantnosqldb.appdomain.cloud"

authenticator = IAMAuthenticator(IBM_CLOUD_APIKEY)

service = CloudantV1(authenticator=authenticator)

service.set_service_url(url)

# %%
# Create the patient_info database if it doesn't exist
db_name = "patient_info"

try:
    put_database_result = service.put_database(db=db_name).get_result()
    if put_database_result["ok"]:
        print(f'"{db_name}" database created.')
except ApiException as ae:
    if ae.status_code == 412:
        print(f'Cannot create "{db_name}" database, it already exists.')

# Create a sample document for patient info
patient_id = 1
visit_id = 1

patient_document = {
    "patient_id": patient_id,
    "nric": "S1234567A",
    "first_name": "Jane",
    "last_name": "Doe",
    "email": "janeDoe@gmail.com",
    "additional_info": ["smoker", "seafood allergy", "nut allergy", "pregnant"],
    "visits": [
        {
            "visit_id": visit_id,
            "prescription_info": [
                "Methotrexate, Dosage: 15 mg, Frequency: once a week, Instructions: Start with a low dose and monitor for side effects",
                "Ibuprofen, Dosage: 400 mg, Frequency: as needed, Instructions: for pain and swelling, not to exceed three times a day",
                "Folic acid, Dosage: 1 mg, Frequency: daily, Instructions: except on the day of Methotrexate, to reduce side effects"
            ],
            "visit_info": [
                "Rheumatoid Arthritis: Patient complains of persistent joint pain and stiffness, particularly in the hands and wrists, worsening in the morning lasting more than one hour. Doctors Remarks: Examination shows symmetrical joint swelling and tenderness in the wrists and MCP (metacarpophalangeal) joints. Symptoms and physical findings suggest an inflammatory process. Rheumatoid factor and anti-CCP (anti-cyclic citrullinated peptide) antibodies tests ordered to confirm diagnosis, along with CRP (C-reactive protein) and ESR (erythrocyte sedimentation rate) to assess inflammation levels."
            ]
        }
    ]
}

# Save the document in the patient_info database
create_document_response = service.post_document(
    db=db_name,
    document=patient_document
).get_result()

print(f"Document inserted: {create_document_response['id']}")
# Out:
# "patient_info" database created.
# Document inserted: 50752d2744f308707b4b75c0955208c2

# %%
# Query the patient_info database
selector = {
    "patient_id": patient_id,
    "visits": {
        "$elemMatch": {
            "visit_id": visit_id
        }
    }
}

response = service.post_find(
    db=db_name,
    selector=selector
).get_result()

if response['docs']:
    patient_doc = response['docs'][0]
    visit_info = next(visit for visit in patient_doc['visits'] if visit['visit_id'] == visit_id)
    print(f"""
    visit_id = {visit_id}
    - prescription_info[]: {visit_info['prescription_info']}
    - visit_info[]: {visit_info['visit_info']}

    patient_id = {patient_doc['patient_id']}
    - NRIC: {patient_doc['nric']}
    - first_name: {patient_doc['first_name']}
    - last_name: {patient_doc['last_name']}
    - email: {patient_doc['email']}
    - additional_info[]: {patient_doc['additional_info']}
    """)
else:
    print("No documents found.")
# Out:
#     visit_id = 1
#     - prescription_info[]: ['Methotrexate, Dosage: 15 mg, Frequency: once a week, Instructions: Start with a low dose and monitor for side effects', 'Ibuprofen, Dosage: 400 mg, Frequency: as needed, Instructions: for pain and swelling, not to exceed three times a day', 'Folic acid, Dosage: 1 mg, Frequency: daily, Instructions: except on the day of Methotrexate, to reduce side effects']
#     - visit_info[]: ['Rheumatoid Arthritis: Patient complains of persistent joint pain and stiffness, particularly in the hands and wrists, worsening in the morning lasting more than one hour. Doctors Remarks: Examination shows symmetrical joint swelling and tenderness in the wrists and MCP (metacarpophalangeal) joints. Symptoms and physical findings suggest an inflammatory process. Rheumatoid factor and anti-CCP (anti-cyclic citrullinated peptide) antibodies tests ordered to confirm diagnosis, along with CRP (C-reactive protein) and ESR (erythrocyte sedimentation rate) to assess inflammation levels.']
#
#     patient_id = 1
#     - NRIC: S1234567A
#     - first_name: Jane
#     - last_name: Doe
#     - email: janeDoe@gmail.com
#     - additional_info[]: ['smoker', 'seafood allergy', 'nut allergy', 'pregnant']

# %%
"""
visit_id = 1
- prescription_info[]: [
  "Methotrexate, Dosage: 15 mg, Frequency: once a week, Instructions: Start with a low dose and monitor for side effects",
  "Ibuprofen, Dosage: 400 mg, Frequency: as needed, Instructions: for pain and swelling, not to exceed three times a day",
  "Folic acid, Dosage: 1 mg, Frequency: daily, Instructions: except on the day of Methotrexate, to reduce side effects"
]
- visit_info[]: [
  "Rheumatoid Arthritis: Patient complains of persistent joint pain and stiffness, particularly in the hands and wrists, worsening in the morning lasting more than one hour. Doctors Remarks: Examination shows symmetrical joint swelling and tenderness in the wrists and MCP (metacarpophalangeal) joints. Symptoms and physical findings suggest an inflammatory process. Rheumatoid factor and anti-CCP (anti-cyclic citrullinated peptide) antibodies tests ordered to confirm diagnosis, along with CRP (C-reactive protein) and ESR (erythrocyte sedimentation rate) to assess inflammation levels."
]

patient_id = 1
- NRIC: "S1234567A"
- first_name: "Jane"
- last_name: "Doe"
- email: "janeDoe@gmail.com"
- additional_info[] : [  "smoker",  "seafood allergy",  "nut allergy",  "pregnant"]

"""
